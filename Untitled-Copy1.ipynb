# %%
import pandas as pd
import boto3
import io
import numpy as np
import json

# %%
movies = pd.read_csv("s3://movie-content-45/clean-data.csv")

# %%
movies.shape
# Out:
# (3099, 16)

# %%
movies.head()
# Out:
#    movie_id                                           overview popularity  \
# 0    783461  when her boyfriend loses a mobster's cash, sav...     56.311
# 1    592508  a fearless, faithful albeit slightly forgetful...     45.077
# 2    864692  a soldier caught by enemies and presumed dead ...     47.611
# 3   1018228  a flight attendant and her boyfriend must stea...     43.789
# 4     20453  rascal. joker. dreamer. genius... you've never...      37.26
#
#           release_date                title vote_average vote_count  \
# 0  2022-02-04 00:00:00         looop lapeta          6.2       54.0
# 1  2021-11-05 00:00:00         sooryavanshi          5.8      133.0
# 2  2023-01-25 00:00:00              pathaan          6.7       70.0
# 3  2023-03-24 00:00:00  chor nikal ke bhaga          7.2       55.0
# 4  2009-12-25 00:00:00             3 idiots          8.0     2052.0
#
#                       genres  \
# 0        action comedy crime
# 1      action crime thriller
# 2  action adventure thriller
# 3             crime thriller
# 4               drama comedy
#
#                                             keywords     month    year  \
# 0              ['remake','loooplapeta','saadesaati']  february  2022.0
# 1  ['police','sequel','policeofficer','copuniverse']  november  2021.0
# 2  ['spy','fakedeath','spythriller','spyuniverse'...   january  2023.0
# 3                      ['heist','airplanehijacking']     march  2023.0
# 4  ['suicide','suicideattempt','college','musical...  december  2009.0
#
#          director       producer  \
# 0       tomtykwer  mukeshchhabra
# 1     rohitshetty     karanjohar
# 2  siddharthanand   adityachopra
# 3       ajaysingh    dineshvijan
# 4     vinaywaikul     rahulnanda
#
#                                               actors  \
# 0  taapseepannu tahirrajbhasin shreyadhanwanthary...
# 1  akshaykumar katrinakaif ajaydevgn ranveersingh...
# 2  shahrukhkhan deepikapadukone johnabraham dimpl...
# 3  yamigautam sunnykaushal sharadkelkar indraneil...
# 4  aamirkhan r.madhavan sharmanjoshi kareenakapoo...
#
#                                           characters  \
# 0       savi satya julia victor mamleshcharanchaddha
# 1  veersooryavanshi riasooryavanshi bajiraosingha...
# 2  pathaan rubinamohsin jim nandini colonelsunill...
# 3  nehagrover ankitsethi parvezshaikh sudhanshuro...
# 4  rancho farhanqureshi rajurastogi pia viru'viru...
#
#                                                 tags
# 0  when her boyfriend loses a mobster s cash  sav...
# 1  a fearless  faithful albeit slightly forgetful...
# 2  a soldier caught by enemies and presumed dead ...
# 3  a flight attendant and her boyfriend must stea...
# 4  rascal  joker  dreamer  genius    you ve never...

# %%
movies.isnull().sum()
# Out:
# movie_id           0
# overview           0
# popularity         0
# release_date       0
# title              0
# vote_average       0
# vote_count         0
# genres           315
# keywords           0
# month              0
# year               0
# director         587
# producer        1453
# actors            33
# characters        44
# tags               0
# dtype: int64

# %%
movies.columns
# Out:
# Index(['movie_id', 'overview', 'popularity', 'release_date', 'title',
#        'vote_average', 'vote_count', 'genres', 'keywords', 'month', 'year',
#        'director', 'producer', 'actors', 'characters', 'tags'],
#       dtype='object')

# %%
movies = movies[['movie_id', 'overview','title','genres','keywords','director','producer','actors','tags']]
movies.head()
# Out:
#    movie_id                                           overview  \
# 0    783461  when her boyfriend loses a mobster's cash, sav...
# 1    592508  a fearless, faithful albeit slightly forgetful...
# 2    864692  a soldier caught by enemies and presumed dead ...
# 3   1018228  a flight attendant and her boyfriend must stea...
# 4     20453  rascal. joker. dreamer. genius... you've never...
#
#                  title                     genres  \
# 0         looop lapeta        action comedy crime
# 1         sooryavanshi      action crime thriller
# 2              pathaan  action adventure thriller
# 3  chor nikal ke bhaga             crime thriller
# 4             3 idiots               drama comedy
#
#                                             keywords        director  \
# 0              ['remake','loooplapeta','saadesaati']       tomtykwer
# 1  ['police','sequel','policeofficer','copuniverse']     rohitshetty
# 2  ['spy','fakedeath','spythriller','spyuniverse'...  siddharthanand
# 3                      ['heist','airplanehijacking']       ajaysingh
# 4  ['suicide','suicideattempt','college','musical...     vinaywaikul
#
#         producer                                             actors  \
# 0  mukeshchhabra  taapseepannu tahirrajbhasin shreyadhanwanthary...
# 1     karanjohar  akshaykumar katrinakaif ajaydevgn ranveersingh...
# 2   adityachopra  shahrukhkhan deepikapadukone johnabraham dimpl...
# 3    dineshvijan  yamigautam sunnykaushal sharadkelkar indraneil...
# 4     rahulnanda  aamirkhan r.madhavan sharmanjoshi kareenakapoo...
#
#                                                 tags
# 0  when her boyfriend loses a mobster s cash  sav...
# 1  a fearless  faithful albeit slightly forgetful...
# 2  a soldier caught by enemies and presumed dead ...
# 3  a flight attendant and her boyfriend must stea...
# 4  rascal  joker  dreamer  genius    you ve never...

# %%
movies['overview'] = movies['overview'].fillna('')

movies['genres'] = movies['genres'].fillna('[]')
movies['keywords'] = movies['keywords'].fillna('[]')
movies['actors'] = movies['actors'].fillna('[]')
movies['director'] = movies['director'].fillna('[]')

# %%
import ast

def convert(obj):
    try:
        return [i['name'] for i in ast.literal_eval(obj)]
    except:
        return []

# %%
movies.loc[:, 'genres'] = movies['genres'].apply(convert)
movies.loc[:, 'keywords'] = movies['keywords'].apply(convert)
movies.loc[:, 'actors'] = movies['actors'].apply(convert)
movies.loc[:, 'director'] = movies['director'].apply(convert)
movies.loc[:, 'overview'] = movies['overview'].apply(lambda x: str(x).split())
# Combine all features into one list
for col in ['overview', 'genres', 'keywords', 'actors', 'director']:
    movies[col] = movies[col].apply(lambda x: x if isinstance(x, list) else [])
    
def combine_features(row):
    return row['overview'] + row['genres'] + row['keywords'] + row['actors'] + row['director']

movies['tags'] = movies.apply(combine_features, axis=1)

# Convert tags list into a single string for TF-IDF
movies['tags'] = movies['tags'].apply(lambda x: " ".join([str(i).replace(" ", "") for i in x]).lower())

# Drop rows with empty tags
movies = movies[movies['tags'] != '']
movies.reset_index(drop=True, inplace=True)

# Check final dataframe
movies[['title', 'tags']].head()
# Out:
#                  title                                               tags
# 0         looop lapeta  ['when', 'her', 'boyfriend', 'loses', 'a', "mo...
# 1         sooryavanshi  ['a', 'fearless,', 'faithful', 'albeit', 'slig...
# 2              pathaan  ['a', 'soldier', 'caught', 'by', 'enemies', 'a...
# 3  chor nikal ke bhaga  ['a', 'flight', 'attendant', 'and', 'her', 'bo...
# 4             3 idiots  ['rascal.', 'joker.', 'dreamer.', 'genius...',...

# %%
new_df = df[['movie_id', 'title', 'tags']]
new_df.head()
# Out:
#     movie_id                title  \
# 0   783461.0         looop lapeta
# 1   592508.0         sooryavanshi
# 2   864692.0              pathaan
# 3  1018228.0  chor nikal ke bhaga
# 4    20453.0             3 idiots
#
#                                                 tags
# 0  ['when', 'her', 'boyfriend', 'loses', 'a', "mo...
# 1  ['a', 'fearless,', 'faithful', 'albeit', 'slig...
# 2  ['a', 'soldier', 'caught', 'by', 'enemies', 'a...
# 3  ['a', 'flight', 'attendant', 'and', 'her', 'bo...
# 4  ['rascal.', 'joker.', 'dreamer.', 'genius...',...

# %%
clean_path = 's3://movie-content-45/tmdb-clean/movies_clean.csv'
new_df.to_csv(clean_path, index=False)
print(f"Clean data uploaded to: {clean_path}")
# Out:
# Clean data uploaded to: s3://movie-content-45/tmdb-clean/movies_clean.csv

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
df = pd.read_csv("s3://movie-content-45/tmdb-clean/movies_clean.csv")
df.head()
# Out:
#     movie_id                title  \
# 0   783461.0         looop lapeta
# 1   592508.0         sooryavanshi
# 2   864692.0              pathaan
# 3  1018228.0  chor nikal ke bhaga
# 4    20453.0             3 idiots
#
#                                                 tags
# 0  ['when', 'her', 'boyfriend', 'loses', 'a', "mo...
# 1  ['a', 'fearless,', 'faithful', 'albeit', 'slig...
# 2  ['a', 'soldier', 'caught', 'by', 'enemies', 'a...
# 3  ['a', 'flight', 'attendant', 'and', 'her', 'bo...
# 4  ['rascal.', 'joker.', 'dreamer.', 'genius...',...

# %%
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
vectors = tfidf.fit_transform(movies['tags']).toarray()

# Save the TF-IDF vectorizer for later use
with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf, f)

# %%
cosine_sim = cosine_similarity(vectors,vectors)

# Save similarity matrix for later
with open('cosine_sim.pkl', 'wb') as f:
    pickle.dump(cosine_sim, f)

# %%
indices = pd.Series(df.index, index=df['title']).drop_duplicates()

# Save the mapping
with open('indices.pkl', 'wb') as f:
    pickle.dump(indices, f)

# %%
def recommend(title, cosine_sim=cosine_sim):
    movie_title_lower = title.lower()
    # Check if the movie exists
    filtered = new_df[new_df['title'].str.lower() == movie_title_lower]
    if filtered.empty:
        print(f"Sorry, we don't have the movie '{title}' in our database.")
        return None
    idx = filtered.index[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # top 10 similar movies
    movie_indices = [i[0] for i in sim_scores]
    return new_df['title'].iloc[movie_indices]

# %%
recommendations = recommend("Lagaan")
if recommendations is None:
    print("No recommendations available for 'Laggan'.")
else:
    print("Recommended movies for 'Lagaan':")
    for movie in recommendations:
        print(movie)
# Out:
# Sorry, we don't have the movie 'Lagaan' in our database.
# No recommendations available for 'Laggan'.

# %%
import pickle

# Save cleaned dataset
with open('movies.pkl', 'wb') as f:
    pickle.dump(df, f)

# Save TF-IDF vectorizer
with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf, f)

# Save cosine similarity matrix
with open('cosine_sim.pkl', 'wb') as f:
    pickle.dump(cosine_sim, f)

# Save title to index mapping
with open('indices.pkl', 'wb') as f:
    pickle.dump(indices, f)

# %%
with open('movies.pkl', 'rb') as f:
    df = pickle.load(f)

with open('tfidf_vectorizer.pkl', 'rb') as f:
    tfidf = pickle.load(f)

with open('cosine_sim.pkl', 'rb') as f:
    cosine_sim = pickle.load(f)

with open('indices.pkl', 'rb') as f:
    indices = pickle.load(f)

# %%
import os
print(os.getcwd())
# Out:
# /home/ec2-user/SageMaker

# %%
s3 = boto3.client('s3')
bucket_name = 'movie-content-45'  # replace with your bucket name

# List of files
files = ['tfidf_vectorizer.pkl', 'cosine_sim.pkl', 'indices.pkl', 'movies.pkl']

for file in files:
    local_path = f'/home/ec2-user/SageMaker/{file}'
    s3_key = f'models/{file}'  # folder path in S3
    s3.upload_file(local_path, bucket_name, s3_key)
    print(f"{file} uploaded to s3://{bucket_name}/{s3_key}")
# Out:
# tfidf_vectorizer.pkl uploaded to s3://movie-content-45/models/tfidf_vectorizer.pkl
# cosine_sim.pkl uploaded to s3://movie-content-45/models/cosine_sim.pkl
# indices.pkl uploaded to s3://movie-content-45/models/indices.pkl
# movies.pkl uploaded to s3://movie-content-45/models/movies.pkl
